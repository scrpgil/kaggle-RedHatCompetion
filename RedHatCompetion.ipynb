# %%
# data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# machine learning
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.linear_model import Perceptron
from sklearn.linear_model import SGDClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
#data analysis and wrangling
import pandas as pd
import numpy as np
import random as rnd

# %%
# visualization
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
people_df = pd.read_csv('./input/people.csv')
people_df
# Out:
#          people_id  char_1      group_1  char_2        date   char_3   char_4  \
# 0          ppl_100  type 2  group 17304  type 2  2021-06-29   type 5   type 5
# 1       ppl_100002  type 2   group 8688  type 3  2021-01-06  type 28   type 9
# 2       ppl_100003  type 2  group 33592  type 3  2022-06-10   type 4   type 8
# 3       ppl_100004  type 2  group 22593  type 3  2022-07-20  type 40  type 25
# 4       ppl_100006  type 2   group 6534  type 3  2022-07-27  type 40  type 25
# 5        ppl_10001  type 2  group 25417  type 3  2022-10-14   type 6   type 6
# 6       ppl_100010  type 2  group 17304  type 2  2022-09-01   type 8   type 7
# 7       ppl_100013  type 2   group 4204  type 3  2023-01-24   type 4   type 8
# 8       ppl_100019  type 2  group 45749  type 3  2023-03-26  type 40  type 25
# 9       ppl_100025  type 2  group 36096  type 3  2022-08-26  type 14   type 6
# 10      ppl_100028  type 2  group 17304  type 2  2023-04-21  type 40  type 25
# ...

# %%
act_test_df = pd.read_csv('./input/act_test.csv')
act_test_df
# Out:
#          people_id   activity_id        date activity_category   char_1  \
# 0       ppl_100004   act1_249281  2022-07-20            type 1   type 5
# 1       ppl_100004   act2_230855  2022-07-20            type 5      NaN
# 2        ppl_10001   act1_240724  2022-10-14            type 1  type 12
# 3        ppl_10001    act1_83552  2022-11-27            type 1  type 20
# 4        ppl_10001  act2_1043301  2022-10-15            type 5      NaN
# 5        ppl_10001   act2_112890  2022-11-27            type 5      NaN
# 6        ppl_10001  act2_1169930  2022-10-15            type 5      NaN
# 7        ppl_10001  act2_1924448  2022-10-15            type 5      NaN
# 8        ppl_10001  act2_1953554  2022-10-15            type 5      NaN
# 9        ppl_10001  act2_1971739  2022-11-28            type 5      NaN
# 10       ppl_10001  act2_2839282  2022-10-16            type 5      NaN
# 11       ppl_10001  act2_2889351  2022-11-27            type 5      NaN
# ...

# %%
act_train_df = pd.read_csv('./input/act_train.csv')
act_train_df
# Out:
#           people_id   activity_id        date activity_category char_1 char_2  \
# 0           ppl_100  act2_1734928  2023-08-26            type 4    NaN    NaN
# 1           ppl_100  act2_2434093  2022-09-27            type 2    NaN    NaN
# 2           ppl_100  act2_3404049  2022-09-27            type 2    NaN    NaN
# 3           ppl_100  act2_3651215  2023-08-04            type 2    NaN    NaN
# 4           ppl_100  act2_4109017  2023-08-26            type 2    NaN    NaN
# 5           ppl_100   act2_898576  2023-08-04            type 4    NaN    NaN
# 6        ppl_100002  act2_1233489  2022-11-23            type 2    NaN    NaN
# 7        ppl_100002  act2_1623405  2022-11-23            type 2    NaN    NaN
# 8        ppl_100003  act2_1111598  2023-02-07            type 2    NaN    NaN
# 9        ppl_100003  act2_1177453  2023-06-28            type 2    NaN    NaN
# 10       ppl_100003   act2_133509  2022-08-10            type 4    NaN    NaN
# ...

# %%
ss_df = pd.read_csv('./input/sample_submission.csv')
ss_df
# Out:
#         activity_id  outcome
# 0            act1_1        0
# 1       act1_100006        0
# 2       act1_100050        0
# 3       act1_100065        0
# 4       act1_100068        0
# 5       act1_100100        0
# 6       act1_100109        0
# 7        act1_10012        0
# 8       act1_100135        0
# 9       act1_100166        0
# 10      act1_100171        0
# 11      act1_100173        0
# 12      act1_100181        0
# 13      act1_100187        0
# 14       act1_10021        0
# 15      act1_100211        0
# 16      act1_100223        0
# 17      act1_100236        0
# 18      act1_100240        0
# 19      act1_100244        0
# 20      act1_100247        0
# 21      act1_100267        0
# 22      act1_100276        0
# 23      act1_100302        0
# 24      act1_100307        0
# 25      act1_100308        0
# 26      act1_100315        0
# 27      act1_100326        0
# 28       act1_10033        0
# 29      act1_100331        0
# ...             ...      ...
# ...

# %%
print(act_train_df.columns.values)
# Out:
# ['people_id' 'activity_id' 'date' 'activity_category' 'char_1' 'char_2'
#  'char_3' 'char_4' 'char_5' 'char_6' 'char_7' 'char_8' 'char_9' 'char_10'
#  'outcome']

# %%
act_train_df.head()
# Out:
#   people_id   activity_id        date activity_category char_1 char_2 char_3  \
# 0   ppl_100  act2_1734928  2023-08-26            type 4    NaN    NaN    NaN
# 1   ppl_100  act2_2434093  2022-09-27            type 2    NaN    NaN    NaN
# 2   ppl_100  act2_3404049  2022-09-27            type 2    NaN    NaN    NaN
# 3   ppl_100  act2_3651215  2023-08-04            type 2    NaN    NaN    NaN
# 4   ppl_100  act2_4109017  2023-08-26            type 2    NaN    NaN    NaN
#
#   char_4 char_5 char_6 char_7 char_8 char_9  char_10  outcome
# 0    NaN    NaN    NaN    NaN    NaN    NaN  type 76        0
# 1    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0
# 2    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0
# 3    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0
# 4    NaN    NaN    NaN    NaN    NaN    NaN   type 1        0

# %%
act_train_df.info()
print('_'*40)
act_test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2197291 entries, 0 to 2197290
# Data columns (total 15 columns):
# people_id            object
# activity_id          object
# date                 object
# activity_category    object
# char_1               object
# char_2               object
# char_3               object
# char_4               object
# char_5               object
# char_6               object
# char_7               object
# char_8               object
# char_9               object
# char_10              object
# outcome              int64
# dtypes: int64(1), object(14)
# memory usage: 251.5+ MB
# ________________________________________
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498687 entries, 0 to 498686
# Data columns (total 14 columns):
# people_id            498687 non-null object
# activity_id          498687 non-null object
# date                 498687 non-null object
# activity_category    498687 non-null object
# ...

# %%
act_train_df.head()
X = act_train_df.drop('outcome', axis=1)
train_y = act_train_df.outcome

# %%
train_X = X.fillna(0)

# %%
train_X.head()
# Out:
#   people_id   activity_id        date activity_category char_1 char_2 char_3  \
# 0   ppl_100  act2_1734928  2023-08-26            type 4      0      0      0
# 1   ppl_100  act2_2434093  2022-09-27            type 2      0      0      0
# 2   ppl_100  act2_3404049  2022-09-27            type 2      0      0      0
# 3   ppl_100  act2_3651215  2023-08-04            type 2      0      0      0
# 4   ppl_100  act2_4109017  2023-08-26            type 2      0      0      0
#
#   char_4 char_5 char_6 char_7 char_8 char_9  char_10
# 0      0      0      0      0      0      0  type 76
# 1      0      0      0      0      0      0   type 1
# 2      0      0      0      0      0      0   type 1
# 3      0      0      0      0      0      0   type 1
# 4      0      0      0      0      0      0   type 1

# %%
## people .csv と結合する必要あり

# %%
# pd.get_dummies(train_X['people_id'])

# %%
# from sklearn.preprocessing import OneHotEncoder

# enc = OneHotEncoder(categories="auto", sparse=False, dtype=np.float32)
# onehot_X = enc.fit_transform(train_X)

# %%
train_merge_X =  pd.merge(train_X, people_df,how="inner", on='people_id',  suffixes=('', '_people'))

# %%
train_merge_X =  train_merge_X.fillna(0)

# %%
# train_merge_X['people_id'].value_counts()

# %%
encoded =  pd.factorize(train_merge_X['people_id'])
train_merge_X['people_id'] = encoded[0]

# %%
encoded =  pd.factorize(train_merge_X['activity_id'])
train_merge_X['activity_id'] = encoded[0]

# %%
encoded =  pd.factorize(train_merge_X['activity_category'])
train_merge_X['activity_category'] = encoded[0]

# %%
train_merge_X['char_10'][20]
# Out:
# 1

# %%
for key in ['char_1',
       'char_2', 'char_3', 'char_4', 'char_5', 'char_6', 'char_7',
       'char_8', 'char_9', 'char_10', 'char_1_people', 'group_1',
       'char_2_people', 'date_people', 'char_3_people', 'char_4_people',
       'char_5_people', 'char_6_people', 'char_7_people', 'char_8_people',
       'char_9_people', 'char_10_people', 'char_11', 'char_12', 'char_13',
       'char_14', 'char_15', 'char_16', 'char_17', 'char_18', 'char_19',
       'char_20', 'char_21', 'char_22', 'char_23', 'char_24', 'char_25',
       'char_26', 'char_27', 'char_28', 'char_29', 'char_30', 'char_31',
       'char_32', 'char_33', 'char_34', 'char_35', 'char_36', 'char_37',
       'char_38']:
    if type(train_merge_X[key][0]) is str:
        encoded =  pd.factorize(train_merge_X[key])
        train_merge_X[key] = encoded[0]

# %%
train_merge_X['date'] = pd.to_datetime(train_merge_X['date']).dt.tz_localize('Asia/Tokyo')
# Out:
#    people_id  activity_id                      date  activity_category char_1  \
# 0          0            0 2023-08-26 00:00:00+09:00                  0      0
# 1          0            1 2022-09-27 00:00:00+09:00                  1      0
# 2          0            2 2022-09-27 00:00:00+09:00                  1      0
# 3          0            3 2023-08-04 00:00:00+09:00                  1      0
# 4          0            4 2023-08-26 00:00:00+09:00                  1      0
#
#   char_2 char_3 char_4 char_5 char_6   ...   char_29 char_30 char_31 char_32  \
# 0      0      0      0      0      0   ...     False    True    True   False
# 1      0      0      0      0      0   ...     False    True    True   False
# 2      0      0      0      0      0   ...     False    True    True   False
# 3      0      0      0      0      0   ...     False    True    True   False
# 4      0      0      0      0      0   ...     False    True    True   False
#
# ...

# %%
train_merge_X['date'] = train_merge_X['date'].astype('int64')
train_merge_X.head()
# Out:
#    people_id  activity_id                 date  activity_category char_1  \
# 0          0            0  1692975600000000000                  0      0
# 1          0            1  1664204400000000000                  1      0
# 2          0            2  1664204400000000000                  1      0
# 3          0            3  1691074800000000000                  1      0
# 4          0            4  1692975600000000000                  1      0
#
#   char_2 char_3 char_4 char_5 char_6   ...    char_29 char_30 char_31  \
# 0      0      0      0      0      0   ...      False    True    True
# 1      0      0      0      0      0   ...      False    True    True
# 2      0      0      0      0      0   ...      False    True    True
# 3      0      0      0      0      0   ...      False    True    True
# 4      0      0      0      0      0   ...      False    True    True
#
#    char_32  char_33  char_34  char_35  char_36  char_37  char_38
# ...

# %%
train_drop_X = train_merge_X.drop(['char_1', 'char_2', 'char_3', 'char_4', 'char_5', 'char_6', 'char_7', 'char_8', 'char_9', 'char_10', 'char_1_people', 'group_1', 'char_2_people', 'date_people', 'char_3_people', 'char_4_people', 'char_5_people', 'char_6_people', 'char_7_people', 'char_8_people', 'char_9_people', 'char_10_people', 'char_11', 'char_12', 'char_13', 'char_14', 'char_15', 'char_16', 'char_17', 'char_18', 'char_19', 'char_20', 'char_21', 'char_22', 'char_23', 'char_24', 'char_25', 'char_26', 'char_27', 'char_28', 'char_29', 'char_30', 'char_31', 'char_32', 'char_33', 'char_34', 'char_35', 'char_36', 'char_37', 'char_38']
                   ,                   axis=1)

# %%
test_x = act_test_df.fillna(0)
test_x =  pd.merge(test_x, people_df,how="inner", on='people_id',  suffixes=('', '_people'))

# %%
encoded =  pd.factorize(test_x['people_id'])
test_x['people_id'] = encoded[0]
encoded =  pd.factorize(test_x['activity_id'])
test_x['activity_id'] = encoded[0]
encoded =  pd.factorize(test_x['activity_category'])
test_x['activity_category'] = encoded[0]

# %%
for key in ['char_1',
       'char_2', 'char_3', 'char_4', 'char_5', 'char_6', 'char_7',
       'char_8', 'char_9', 'char_10', 'char_1_people', 'group_1',
       'char_2_people', 'date_people', 'char_3_people', 'char_4_people',
       'char_5_people', 'char_6_people', 'char_7_people', 'char_8_people',
       'char_9_people', 'char_10_people', 'char_11', 'char_12', 'char_13',
       'char_14', 'char_15', 'char_16', 'char_17', 'char_18', 'char_19',
       'char_20', 'char_21', 'char_22', 'char_23', 'char_24', 'char_25',
       'char_26', 'char_27', 'char_28', 'char_29', 'char_30', 'char_31',
       'char_32', 'char_33', 'char_34', 'char_35', 'char_36', 'char_37',
       'char_38']:
    if type(test_x[key][0]) is str:
        encoded =  pd.factorize(test_x[key])
        test_x[key] = encoded[0]

# %%
test_x['date'] = pd.to_datetime(test_x['date']).dt.tz_localize('Asia/Tokyo')
test_x['date'] = test_x['date'].astype('int64')

# %%
test_x = test_x.drop(['char_1', 'char_2', 'char_3', 'char_4', 'char_5', 'char_6', 'char_7', 'char_8', 'char_9', 'char_10', 'char_1_people', 'group_1', 'char_2_people', 'date_people', 'char_3_people', 'char_4_people', 'char_5_people', 'char_6_people', 'char_7_people', 'char_8_people', 'char_9_people', 'char_10_people', 'char_11', 'char_12', 'char_13', 'char_14', 'char_15', 'char_16', 'char_17', 'char_18', 'char_19', 'char_20', 'char_21', 'char_22', 'char_23', 'char_24', 'char_25', 'char_26', 'char_27', 'char_28', 'char_29', 'char_30', 'char_31', 'char_32', 'char_33', 'char_34', 'char_35', 'char_36', 'char_37', 'char_38']
                   ,                   axis=1)

# %%
test_x.head()
# Out:
#    people_id  activity_id                 date  activity_category
# 0          0            0  1658242800000000000                  0
# 1          0            1  1658242800000000000                  1
# 2          1            2  1665673200000000000                  0
# 3          1            3  1669474800000000000                  0
# 4          1            4  1665759600000000000                  1

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(random_state=0)
clf = clf.fit(train_drop_X, train_y)
# Out:
# /anaconda2/envs/py37/lib/python3.7/site-packages/sklearn/ensemble/forest.py:246: FutureWarning: The default value of n_estimators will change from 10 in version 0.20 to 100 in 0.22.
#   "10 in version 0.20 to 100 in 0.22.", FutureWarning)

# %%
pred = clf.predict(test_x)
pred
# fpr, tpr, thresholds = roc_curve(test_y, pred, pos_label=1)
# auc(fpr, tpr)
# accuracy_score(pred, test_y)
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
# PassengerIdを取得
PassengerId = np.array(test["PassengerId"]).astype(int)
 
# my_prediction(予測データ）とPassengerIdをデータフレームへ落とし込む
my_solution = pd.DataFrame(my_prediction, PassengerId, columns = ["Survived"])
 
# my_tree_one.csvとして書き出し
my_solution.to_csv("my_tree_one.csv", index_label = ["PassengerId"])

# %%
pred
# Out:
# array([0, 0, 1, ..., 0, 0, 0])

# %%
# activity_id	outcome

# my_solution = pd.DataFrame(act_test_df["activity_id"], pred, columns = ["activity_id", "outcome"])
my_solution = act_test_df.drop(
    ['people_id', 'date','activity_category','char_1','char_2', 'char_3','char_4','char_5','char_6','char_7','char_8','char_9','char_10'
 ],
    axis=1
)

# %%
my_solution.head()
# Out:
#     activity_id
# 0   act1_249281
# 1   act2_230855
# 2   act1_240724
# 3    act1_83552
# 4  act2_1043301

# %%
my_solution["outcome"] = pred

# %%
my_solution
# Out:
#          activity_id  outcome
# 0        act1_249281        0
# 1        act2_230855        0
# 2        act1_240724        1
# 3         act1_83552        0
# 4       act2_1043301        1
# 5        act2_112890        1
# 6       act2_1169930        1
# 7       act2_1924448        1
# 8       act2_1953554        1
# 9       act2_1971739        1
# 10      act2_2839282        1
# 11      act2_2889351        1
# 12      act2_3238933        1
# 13      act2_3384798        1
# 14      act2_3701358        1
# 15      act2_3715695        1
# 16      act2_3734085        1
# 17      act2_3961391        1
# 18      act2_4167474        1
# 19      act2_4397847        1
# 20      act2_4649285        1
# 21       act2_538607        1
# 22       act2_584216        1
# 23       act2_596561        1
# 24       act2_649143        1
# 25       act2_659237        1
# 26       act2_688604        1
# 27       act1_218751        1
# 28       act1_383524        1
# 29      act2_3973689        1
# ...

# %%
my_solution.to_csv("my_tree_one.csv")

# %%
import lightgbm as lgb
# Scikit-learn（評価算出）
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-9-ccd707964ecd> in <module>
# ----> 1 import lightgbm as lgb
#       2 # Scikit-learn（評価算出）
#       3 from sklearn.metrics import confusion_matrix
#       4 from sklearn.metrics import accuracy_score
#
# ModuleNotFoundError: No module named 'lightgbm'
